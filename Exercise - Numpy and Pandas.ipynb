# %% [markdown]
# # Exercise - Numpy and Pandas
#
# In this notebook we will practice what we learned on numpy and pandas. This is relatively an easy week so I go harsh on the exercises a bit. Less gooo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 1
# A. What are packages/libraries and how to install them?
#
#     Answer-->
# B. inside the notebook, install and import a package called "random2"
#
# C. provide the link to the documentation of random2 and skim through it yourself, what is this library for?
#
#     Link-->
#     Answer-->
#
# D. Use any function of your choice from random2 package
#
#
# E. import pandas and Numpy

# %% [markdown]
# ## Question 2
#
# **Pandas**
#
#
# * Create a pandas series with three items [" butter type", "price","stock"]
# * create a pandas dataframe with columns named as items of the previous series
# * create a row in this dataframe for a peanut butter priced 10 pounds and there is 20 of it in stock
# * create another row for almond butter priced 30 pounds and there is 30 of it in stock

# %% [markdown]
# ## Question 3
# **Pandas**
#
#
# A.
# * read the csv file provided name house_prices.csv
# * print out the columns of this table , each column in a line alone
#   meaning:
#         column1
#         column2
#         column3
# * view the first 4 rows
# * print the value of the 10th row in the 3rd column
#
# B.
# * what are the datatypes of each column ?
# * what is the shape of the dataframe
# * use .info() and .describe() methods , what do you observe in each
#
#         Answer-->

# %% [markdown]
# ## Question 4
# **Numpy**
#
# A.
#
# Numpy speeds things up, and numpy array are much more efficient that using lists,why is that?
#
#     Answer-->
#
#
#
# B.
# * create a 1D,2D and a 3D array
# * for each , print out
#     * array itself
#     * shape
#     * size
#     * number of dimensions
# * transform the 2D array you created to a pandas dataframe
# * then transform it back to a numpy array
#
# C.
# * access the item in the first row ,first column and 2nd block of the 3d array
# * print the only the first column of the 2d array
# * access the first 3 items of the 1d array

# %% [markdown]
# ## Question 5
# **Numpy**
#
# A. create multiple arrays of the same shape of 3 by 3 using :
#   * np.ones
#   * np.zeros
#   * np.arange with values that range from 1 to 9
#   * np.linspace
#
#
# B. add all the arrays together creating an new array and call it : "sum_array"
#
# C. element-wise multiply all the arrays together creating a new array and call it : "zero_array"
#
# D. do a dot product multplication using np.dot between the zeros array and ones array

# %% [markdown]
# ## Question 6
# **Numpy**
#
# A.
# If we do a dot product between two arrays , one with shape (2,3) and one with shape (3,2) , would this yield an error? If not, what would be the shape of the output array?
#
#
#
# B.
# Considering rules of broadcasting mathmetical operations between arrays of the following specified shapes , which would yield an error and which is compatible ?
#
#     Answer
#     (2,1) , (1,) --->
#     (5,5,3), (2,5,3) -->
#     (5,5,3), (5,3) -->
#     (3,3,4), (4,)-->
