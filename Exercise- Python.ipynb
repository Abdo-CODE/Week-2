# %% [markdown]
# # Python Excercise Again .....
#
# in this notebook,I will try to force you to revise what we learned in the first session, while making things a bit more challenging
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 1  (Medium difficulty)
#
# A. Using a for loop, print out this shape:
#
#             *
#             **
#             ***
#             ****
#             *****
#             ******
#             *******
#             ********
#             *********
#
#
# B. how bout this shape too (sorry):
#
#                 *
#                 **
#                 ***
#                 ****
#                 *****
#                 ******
#                 *******
#                 ********
#                 *********
#                 ********
#                 *******
#                 ******
#                 *****
#                 ****
#                 ***
#                 **
#                 *

# %% [markdown]
# ## Question 2  (Hard difficulty)
# ####
#
# A.do your on search on the "modulo opertaion in python"
#
# B. create a list that includes all numbers from 0 to 100
#
# C.
# * create empty lists with the following names : prime, even, odd, mult_10
# * by iterating over the created list:
#     * add prime numbers to *prime*
#     * add odd numbers to *odd*
#     * add even numbers to *even*
#     * add multiples of 10 to *mult_10*

# %% [markdown]
# ## Question 3 (Easy difficulty)
#
# A. create a function the takes a name as input and prints the name 5 times
#
# B. create another function that captilises the first letter of word taken as input
#
# C. implement both functons on the following list
#     ["ali","abdelhameed", "alaa",abdelrahman","nooreldeen",fawzewya","mark","sheha", "fatheya", "omar" , "amr"]
#
# D.iterate over the previous list
#
#         * print "long name" if name has more than or equal 7 characters
#         * print "medium name" if name has more than 5 characters but less than 7
#         * print "short name" if name has less than or equal 5 characters
#         *  print "STOP HERE" and break loop if you came across fatheya

# %% [markdown]
# ## Question 4
#
# A. what is the difference between a local and global variable ?
#
#         Answer -->
# B. What is the difference between a method and a function?
#
#         Answer -->
#
# C. how are for loops and while loops different?
#
#         Answer -->
