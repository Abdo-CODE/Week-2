# %% [markdown]
# # Excersises Notebook
#
# In this notebook, I will try to make you practice what we learned this week :
# * variables
# * loops
# * functions
# * if conditions
#
#
# In this notebook , exercises will start easy then get more and more complicated.
#
# Buckle Up AND SOLVE ALL QUESTIONS EVEN IF THE ANSWER IS WRONG
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 1
# A. Where is a variable created and where is a file saved  in terms of computer architechure  ?
#
# Answer--->
#
# B. define a variable and call it hamada :
# *  assign this variable a value of 40
# *  print out it's type
# *  convert this variable to string

# %% [markdown]
# ### Question 2
# A. the following statement will raise an error :
# ``` python
# "5"+100
# ```
#
# why is that ??
#
# Answer--->
#
# B. define what is a method from your own understanding of methods and functions
#
# Answer--->
#
#
# c. create a string variable with name of fatheya and value of "hello", then try out atleast 3 methods from this link
# https://www.w3schools.com/python/python_ref_string.asp

# %% [markdown]
# ### Question 3
# A. From the iterables that we have learned about :
# * which are unorderd ?
# * which are immutable ?
# * which non-subscriptable ?
# Answer--->
#
# B. Create list [1,2,355,55,1000] then iterate over each item using a for loop and print "high" if value larger than 100 and "low" if value less than 100

# %% [markdown]
# ### Question 4
# --given list of intergars  : gar and list of floats : fts
# ```python
# fts=[1.0,2.0,3.0,5.0,7.0,9.0,20.4,44.66,66.5]
# gar=[1,4,5,6,7,88,100,33,22]
# ```
# * create a dictionary with values of gar as keys and values of ft as values
# * convert first four items in fts to integar and add the sum of gar to each
# * save output in a new list called fts2

# %% [markdown]
# ### Question 5
# * create a function that takes an input and returns value to the power of 10 and prints (old value , new value)
# * implement function on every value of gar

# %% [markdown]
# ### Question 6
# without using the built-in function max(), try to come up with a way to create your own function that returns maximum number in a list , call this function halland()
